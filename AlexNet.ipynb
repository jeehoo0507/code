# %% [markdown]
# # AlexNet

# %% [markdown]
# <div align="center">
#   <img src="img/AlexNet.png" width="700">
# </div>

# %% [markdown]
# **preview**
#
# AlexNet은 기존 CNN의 학습 속도와 과적합 문제를 개선하고, 대규모 데이터와 GPU를 활용해 이미지 인식 성능을 크게 높인 모델이다.
#
# paper : [link](https://proceedings.neurips.cc/paper_files/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf)

# %% [markdown]
# ## problem
